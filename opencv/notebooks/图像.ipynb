# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread('.assets/logo.png')
print(f"图像读取成功, 图像大小: {im.shape[:2]}, 颜色通道数: {im.shape[2]}")

# cv2.imshow('logo', im)

# 关闭坐标轴显示
plt.axis("off")

# 使用 matplotlib 显示图像
plt.imshow(im)
plt.show()
# Out:
# 图像读取成功, 图像大小: (360, 512), 颜色通道数: 3
